# %% [markdown]
# # Read all csv files

# %%
# import libraries
import pandas as pd
import os
import glob

# Read all csv files in the data folder
path = os.getcwd() + '/data'
csv_files = glob.glob(os.path.join(path, "*.csv"))
  
li = []
#loop over csv files and append
for f in csv_files:
    df_s = pd.read_csv(f, index_col=None, header=0)
    li.append(df_s)

df = pd.concat(li, axis=0, ignore_index=True)

# %% [markdown]
# # Data cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1189287 entries, 0 to 1189286
# Data columns (total 39 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   backers_count             1189287 non-null  int64
#  1   blurb                     1189242 non-null  object
#  2   category                  1189287 non-null  object
#  3   converted_pledged_amount  1189287 non-null  int64
#  4   country                   1189287 non-null  object
#  5   country_displayable_name  1189287 non-null  object
#  6   created_at                1189287 non-null  int64
#  7   creator                   1189287 non-null  object
#  8   currency                  1189287 non-null  object
#  9   currency_symbol           1189287 non-null  object
#  10  currency_trailing_code    1189287 non-null  bool
#  11  current_currency          1189287 non-null  object
#  12  deadline                  1189287 non-null  int64
#  13  disable_communication     1189287 non-null  bool
#  14  friends                   900 non-null      object
#  15  fx_rate                   1189287 non-null  float64
#  16  goal                      1189287 non-null  float64
#  17  id                        1189287 non-null  int64
#  18  is_backing                900 non-null      object
#  19  is_starrable              1189287 non-null  bool
#  20  is_starred                900 non-null      object
#  21  launched_at               1189287 non-null  int64
#  22  location                  1188130 non-null  object
#  23  name                      1189287 non-null  object
#  24  permissions               900 non-null      object
#  25  photo                     1189287 non-null  object
#  26  pledged                   1189287 non-null  float64
#  27  profile                   1189287 non-null  object
#  28  slug                      1189287 non-null  object
#  29  source_url                1189287 non-null  object
#  30  spotlight                 1189287 non-null  bool
#  31  staff_pick                1189287 non-null  bool
#  32  state                     1189287 non-null  object
#  33  state_changed_at          1189287 non-null  int64
#  34  static_usd_rate           1189287 non-null  float64
#  35  urls                      1189287 non-null  object
#  36  usd_pledged               1189287 non-null  float64
#  37  usd_type                  1187403 non-null  object
#  38  usd_exchange_rate         319410 non-null   float64
# dtypes: bool(5), float64(6), int64(7), object(21)
# memory usage: 314.2+ MB

# %% [markdown]
# ### Dropping columns that are not relevant to study

# %%
columns_to_drop = df[['backers_count', 'country_displayable_name', 'creator', 'currency',
                      'currency_symbol', 'currency_trailing_code', 'current_currency',
                     'disable_communication', 'friends', 'is_backing', 'is_starrable', 'is_starred',
                     'location', 'permissions', 'photo', 'profile','slug', 'source_url',
                      'spotlight', 'staff_pick','static_usd_rate', 'urls', 'usd_type', 'usd_exchange_rate']]

df.drop(columns_to_drop, axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1189287 entries, 0 to 1189286
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   blurb                     1189242 non-null  object
#  1   category                  1189287 non-null  object
#  2   converted_pledged_amount  1189287 non-null  int64
#  3   country                   1189287 non-null  object
#  4   created_at                1189287 non-null  int64
#  5   deadline                  1189287 non-null  int64
#  6   fx_rate                   1189287 non-null  float64
#  7   goal                      1189287 non-null  float64
#  8   id                        1189287 non-null  int64
#  9   launched_at               1189287 non-null  int64
#  10  name                      1189287 non-null  object
#  11  pledged                   1189287 non-null  float64
#  12  state                     1189287 non-null  object
#  13  state_changed_at          1189287 non-null  int64
#  14  usd_pledged               1189287 non-null  float64
# dtypes: float64(4), int64(6), object(5)
# memory usage: 136.1+ MB

# %% [markdown]
# ### Only keeping projects that were successful or failed

# %%
df = df[(df['state'] == 'successful') | (df['state'] == 'failed')]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1108341 entries, 0 to 1189286
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   blurb                     1108331 non-null  object
#  1   category                  1108341 non-null  object
#  2   converted_pledged_amount  1108341 non-null  int64
#  3   country                   1108341 non-null  object
#  4   created_at                1108341 non-null  int64
#  5   deadline                  1108341 non-null  int64
#  6   fx_rate                   1108341 non-null  float64
#  7   goal                      1108341 non-null  float64
#  8   id                        1108341 non-null  int64
#  9   launched_at               1108341 non-null  int64
#  10  name                      1108341 non-null  object
#  11  pledged                   1108341 non-null  float64
#  12  state                     1108341 non-null  object
#  13  state_changed_at          1108341 non-null  int64
#  14  usd_pledged               1108341 non-null  float64
# dtypes: float64(4), int64(6), object(5)
# memory usage: 135.3+ MB

# %% [markdown]
# ### Dropping the duplicate projects, found by project id

# %%
df.drop_duplicates(subset = 'id', keep = 'first', inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193779 entries, 0 to 1188867
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   blurb                     193777 non-null  object
#  1   category                  193779 non-null  object
#  2   converted_pledged_amount  193779 non-null  int64
#  3   country                   193779 non-null  object
#  4   created_at                193779 non-null  int64
#  5   deadline                  193779 non-null  int64
#  6   fx_rate                   193779 non-null  float64
#  7   goal                      193779 non-null  float64
#  8   id                        193779 non-null  int64
#  9   launched_at               193779 non-null  int64
#  10  name                      193779 non-null  object
#  11  pledged                   193779 non-null  float64
#  12  state                     193779 non-null  object
#  13  state_changed_at          193779 non-null  int64
#  14  usd_pledged               193779 non-null  float64
# dtypes: float64(4), int64(6), object(5)
# memory usage: 23.7+ MB

# %% [markdown]
# ### Fix time values

# %%
from datetime import datetime
import time

# %%
def convert_times(row):
    row['created_at'] = datetime.strptime(time.strftime('%Y-%m-%d %H:%M:%S', 
                                                        time.localtime(row['created_at'])), '%Y-%m-%d %H:%M:%S')
    row['deadline'] = datetime.strptime(time.strftime('%Y-%m-%d %H:%M:%S', 
                                                      time.localtime(row['deadline'])), '%Y-%m-%d %H:%M:%S')
    row['launched_at'] = datetime.strptime(time.strftime('%Y-%m-%d %H:%M:%S', 
                                                         time.localtime(row['launched_at'])), '%Y-%m-%d %H:%M:%S')
    row['state_changed_at'] = datetime.strptime(time.strftime('%Y-%m-%d %H:%M:%S', 
                                                              time.localtime(row['state_changed_at'])), '%Y-%m-%d %H:%M:%S')
    return row

# %%
df = df.apply(convert_times, axis = 1)

# %%
df.head()
# Out:
#                                                blurb  \
# 0  Help Guy and Steph publish their illustrated c...
# 1  A black and white photography book by renowned...
# 2  Sarah, the displaced hero, will empower your c...
# 3  A world ravaged by climate change. A father tr...
# 4  Get Sinned-Angel-Stock & SenshiStock together ...
#
#                                             category  \
# 0  {"id":46,"name":"Children's Books","slug":"pub...
# 1  {"id":280,"name":"Photobooks","slug":"photogra...
# 2  {"id":46,"name":"Children's Books","slug":"pub...
# 3  {"id":285,"name":"Plays","slug":"theater/plays...
# 4  {"id":278,"name":"People","slug":"photography/...
#
#    converted_pledged_amount country          created_at            deadline  \
# 0                      6114      GB 2020-04-16 05:18:45 2020-05-15 01:58:55
# 1                     30850      US 2017-05-29 05:11:31 2017-09-13 14:00:00
# 2                     24292      SE 2016-10-14 06:19:56 2016-12-19 14:59:00
# 3                     13312      US 2017-10-19 15:18:53 2017-12-15 15:11:03
# 4                      3000      US 2017-05-05 08:18:48 2017-06-23 19:00:00
#
#     fx_rate      goal          id         launched_at  \
# 0  1.364080    2500.0  1846656783 2020-04-24 01:58:55
# 1  1.000000   10000.0  2036647097 2017-08-02 06:54:08
# 2  0.119897  218000.0   923683665 2016-11-15 10:13:46
# 3  1.000000   12000.0  1028831108 2017-11-03 15:11:03
# 4  1.000000     750.0  2080833032 2017-06-01 05:02:54
#
#                                                 name   pledged       state  \
# 0  An Illustrated Children's Book - Kindness is C...    5008.0  successful
# 1  The Last of the Hill Farms: Echoes of Vermont'...   30850.0  successful
# 2  Sarah's Journey: An Empowering Adventure Book ...  227101.0  successful
# 3                                  The Promised Land   13312.7  successful
# 4                        Pose References for Artists    3000.0  successful
#
#      state_changed_at   usd_pledged
# 0 2020-05-15 01:58:55   6172.413435
# 1 2017-09-13 14:00:00  30850.000000
# 2 2016-12-19 14:59:00  24904.533814
# 3 2017-12-15 15:11:03  13312.700000
# 4 2017-06-23 19:00:00   3000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193779 entries, 0 to 1188867
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   blurb                     193777 non-null  object
#  1   category                  193779 non-null  object
#  2   converted_pledged_amount  193779 non-null  int64
#  3   country                   193779 non-null  object
#  4   created_at                193779 non-null  datetime64[ns]
#  5   deadline                  193779 non-null  datetime64[ns]
#  6   fx_rate                   193779 non-null  float64
#  7   goal                      193779 non-null  float64
#  8   id                        193779 non-null  int64
#  9   launched_at               193779 non-null  datetime64[ns]
#  10  name                      193779 non-null  object
#  11  pledged                   193779 non-null  float64
#  12  state                     193779 non-null  object
#  13  state_changed_at          193779 non-null  datetime64[ns]
#  14  usd_pledged               193779 non-null  float64
# dtypes: datetime64[ns](4), float64(4), int64(2), object(5)
# memory usage: 23.7+ MB

# %%
df = df[df['launched_at'] > '2020-02']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31953 entries, 0 to 1188732
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   blurb                     31953 non-null  object
#  1   category                  31953 non-null  object
#  2   converted_pledged_amount  31953 non-null  int64
#  3   country                   31953 non-null  object
#  4   created_at                31953 non-null  datetime64[ns]
#  5   deadline                  31953 non-null  datetime64[ns]
#  6   fx_rate                   31953 non-null  float64
#  7   goal                      31953 non-null  float64
#  8   id                        31953 non-null  int64
#  9   launched_at               31953 non-null  datetime64[ns]
#  10  name                      31953 non-null  object
#  11  pledged                   31953 non-null  float64
#  12  state                     31953 non-null  object
#  13  state_changed_at          31953 non-null  datetime64[ns]
#  14  usd_pledged               31953 non-null  float64
# dtypes: datetime64[ns](4), float64(4), int64(2), object(5)
# memory usage: 3.9+ MB

# %% [markdown]
# ### Obtain Categories

# %%
from ast import literal_eval
import numpy as np

# %%
# Make Categories as an attribute
category = df.category.apply(literal_eval)
main_category = []
for i, d in enumerate(category):
    try:
        main_category.append(d['parent_name'])
    except:
        main_category.append(np.nan)
df['main_category'] = main_category
df.main_category.value_counts()
# Out:
# Games           5649
# Technology      3272
# Design          3121
# Publishing      2730
# Art             2670
# Comics          2425
# Film & Video    2218
# Fashion         1677
# Music           1573
# Food            1351
# Crafts           525
# Photography      475
# Journalism       243
# Theater          184
# Dance             58
# Name: main_category, dtype: int64

# %%
sub_category = []
for i, name in enumerate(d['name'] for d in category):
    sub_category.append(name)
df['sub_category'] = sub_category
df.sub_category.value_counts()
# Out:
# Tabletop Games    3849
# Product Design    2590
# Art               1505
# Illustration      1242
# Comic Books       1188
#                   ...
# Photo                4
# Residencies          4
# Workshops            3
# Chiptune             2
# Quilts               1
# Name: sub_category, Length: 160, dtype: int64

# %%
df[df.main_category.isna()]['sub_category'].value_counts()
# Out:
# Art             1505
# Music            428
# Comics           306
# Design           302
# Publishing       293
# Technology       190
# Crafts           169
# Food             155
# Games            121
# Film & Video     112
# Fashion           72
# Journalism        48
# Photography       41
# Theater           24
# Dance             16
# Name: sub_category, dtype: int64

# %%
df.main_category.fillna(df.sub_category, inplace=True)
df.isna().sum()
# Out:
# blurb                       0
# category                    0
# converted_pledged_amount    0
# country                     0
# created_at                  0
# deadline                    0
# fx_rate                     0
# goal                        0
# id                          0
# launched_at                 0
# name                        0
# pledged                     0
# state                       0
# state_changed_at            0
# usd_pledged                 0
# main_category               0
# sub_category                0
# dtype: int64

# %%
df.main_category.value_counts()
# Out:
# Games           5770
# Art             4175
# Technology      3462
# Design          3423
# Publishing      3023
# Comics          2731
# Film & Video    2330
# Music           2001
# Fashion         1749
# Food            1506
# Crafts           694
# Photography      516
# Journalism       291
# Theater          208
# Dance             74
# Name: main_category, dtype: int64

# %% [markdown]
# ### Obtain Country/Region

# %%
df.country.value_counts()
# Out:
# US    17795
# GB     4410
# CA     1912
# DE      925
# AU      835
# FR      822
# ES      768
# IT      741
# MX      734
# HK      685
# NL      328
# SG      314
# SE      309
# JP      292
# CH      191
# DK      181
# BE      147
# NZ      118
# IE      104
# AT      103
# PL       78
# NO       69
# GR       53
# SI       21
# LU       18
# Name: country, dtype: int64

# %%
country_dic = {'GB':'EU', 'CA': 'AM_non_US', 'DE':'EU', 'AU':'AP', 'FR':'EU', 'ES': 'EU', 'IT':'EU', 
               'MX':'AM_non_US','HK':'AP', 'NL':'EU', 'SG':'AP', 'SE':'EU', 'JP':'AP', 'CH':'AP', 'DK':'EU', 
               'BE':'EU', 'NZ':'AP', 'IE':'EU', 'AT':'EU', 'PL':'EU', 'NO':'EU', 'GR':'EU', 'SI':'EU', 'LU':'EU'}
df = df.replace({"country": country_dic})

# %%
df.rename({'country':'region'}, axis = 1, inplace = True)

# %%
df.head()
# Out:
#                                                 blurb  \
# 0   Help Guy and Steph publish their illustrated c...
# 10  Support us by backing! Wearable Blanket featur...
# 17  Yono Clip is the ultimate solution to keep you...
# 24  Our new go to mini rod is ready for all of you...
# 25  Looking for a menstrual cup that is comfortabl...
#
#                                              category  \
# 0   {"id":46,"name":"Children's Books","slug":"pub...
# 10  {"id":28,"name":"Product Design","slug":"desig...
# 17  {"id":28,"name":"Product Design","slug":"desig...
# 24  {"id":28,"name":"Product Design","slug":"desig...
# 25  {"id":28,"name":"Product Design","slug":"desig...
#
#     converted_pledged_amount region          created_at            deadline  \
# 0                       6114     EU 2020-04-16 05:18:45 2020-05-15 01:58:55
# 10                      5643     US 2020-05-27 06:47:29 2020-07-09 09:00:00
# 17                      9857     US 2020-04-15 07:11:52 2020-07-13 05:22:08
# 24                    116629     US 2016-12-27 13:19:41 2020-04-23 19:33:00
# 25                     11880     US 2020-07-17 19:34:35 2020-08-26 23:59:00
#
#     fx_rate     goal          id         launched_at  \
# 0   1.36408   2500.0  1846656783 2020-04-24 01:58:55
# 10  1.00000   5000.0  1091394927 2020-06-09 09:14:06
# 17  1.00000   7700.0  1892452780 2020-06-13 05:22:08
# 24  1.00000  10000.0   591954572 2020-03-24 10:02:22
# 25  1.00000  10000.0  1488247508 2020-07-28 08:05:39
#
#                                                  name    pledged       state  \
# 0   An Illustrated Children's Book - Kindness is C...    5008.00  successful
# 10  Snuggy Buddy Baby - The First Wearable Lovey B...    5643.00  successful
# 17                                          Yono Clip    9857.44  successful
# 24  Tenkara Rod Co. - The Beartooth Rod - Go Anywh...  116629.00  successful
# 25            Kind Cup - the innovative menstrual cup   11880.00  successful
#
#       state_changed_at    usd_pledged main_category      sub_category
# 0  2020-05-15 01:58:55    6172.413435    Publishing  Children's Books
# 10 2020-07-09 09:00:00    5643.000000        Design    Product Design
# 17 2020-07-13 05:22:08    9857.440000        Design    Product Design
# 24 2020-04-23 19:33:00  116629.000000        Design    Product Design
# 25 2020-08-26 23:59:01   11880.000000        Design    Product Design

# %%
df.region.value_counts()
# Out:
# US           17795
# EU            9077
# AM_non_US     2646
# AP            2435
# Name: region, dtype: int64

# %% [markdown]
# ### Standardize currency values

# %%
df.columns
# Out:
# Index(['blurb', 'category', 'converted_pledged_amount', 'region', 'created_at',
#        'deadline', 'fx_rate', 'goal', 'id', 'launched_at', 'name', 'pledged',
#        'state', 'state_changed_at', 'usd_pledged', 'main_category',
#        'sub_category'],
#       dtype='object')

# %%
df['goal'] = df.goal.astype(float)
df['fx_rate'] = df.fx_rate.astype(float)
df['goal_usd'] = df.goal * df.fx_rate
df.rename({'usd_pledged':'pledged_usd'}, axis = 1, inplace = True)
df.head()
# Out:
#                                                 blurb  \
# 0   Help Guy and Steph publish their illustrated c...
# 10  Support us by backing! Wearable Blanket featur...
# 17  Yono Clip is the ultimate solution to keep you...
# 24  Our new go to mini rod is ready for all of you...
# 25  Looking for a menstrual cup that is comfortabl...
#
#                                              category  \
# 0   {"id":46,"name":"Children's Books","slug":"pub...
# 10  {"id":28,"name":"Product Design","slug":"desig...
# 17  {"id":28,"name":"Product Design","slug":"desig...
# 24  {"id":28,"name":"Product Design","slug":"desig...
# 25  {"id":28,"name":"Product Design","slug":"desig...
#
#     converted_pledged_amount region          created_at            deadline  \
# 0                       6114     EU 2020-04-16 05:18:45 2020-05-15 01:58:55
# 10                      5643     US 2020-05-27 06:47:29 2020-07-09 09:00:00
# 17                      9857     US 2020-04-15 07:11:52 2020-07-13 05:22:08
# 24                    116629     US 2016-12-27 13:19:41 2020-04-23 19:33:00
# 25                     11880     US 2020-07-17 19:34:35 2020-08-26 23:59:00
#
#     fx_rate     goal          id         launched_at  \
# 0   1.36408   2500.0  1846656783 2020-04-24 01:58:55
# 10  1.00000   5000.0  1091394927 2020-06-09 09:14:06
# 17  1.00000   7700.0  1892452780 2020-06-13 05:22:08
# 24  1.00000  10000.0   591954572 2020-03-24 10:02:22
# 25  1.00000  10000.0  1488247508 2020-07-28 08:05:39
#
#                                                  name    pledged       state  \
# 0   An Illustrated Children's Book - Kindness is C...    5008.00  successful
# 10  Snuggy Buddy Baby - The First Wearable Lovey B...    5643.00  successful
# 17                                          Yono Clip    9857.44  successful
# 24  Tenkara Rod Co. - The Beartooth Rod - Go Anywh...  116629.00  successful
# 25            Kind Cup - the innovative menstrual cup   11880.00  successful
#
#       state_changed_at    pledged_usd main_category      sub_category  \
# 0  2020-05-15 01:58:55    6172.413435    Publishing  Children's Books
# 10 2020-07-09 09:00:00    5643.000000        Design    Product Design
# 17 2020-07-13 05:22:08    9857.440000        Design    Product Design
# 24 2020-04-23 19:33:00  116629.000000        Design    Product Design
# 25 2020-08-26 23:59:01   11880.000000        Design    Product Design
#
#         goal_usd
# 0    3410.199225
# 10   5000.000000
# 17   7700.000000
# 24  10000.000000
# 25  10000.000000

# %% [markdown]
# ### Get number of words in blurb & name

# %%
def num_words(row):
    try:
        row['blurb_len'] = len(row['blurb'].split())
    except TypeError: 
        print[row['blurb']]
    try:
        row['name_len'] = len(row['name'].split())
    except TypeError:
        print[row['name']]
    return row

# %%
df['blurb'] = df.blurb.astype(str)
df['name'] = df.name.astype(str)
df.apply(num_words, axis = 1)
# Out:
#                                                      blurb  \
# 0        Help Guy and Steph publish their illustrated c...
# 10       Support us by backing! Wearable Blanket featur...
# 17       Yono Clip is the ultimate solution to keep you...
# 24       Our new go to mini rod is ready for all of you...
# 25       Looking for a menstrual cup that is comfortabl...
# ...                                                    ...
# 1187809            Custom built game table made by gamers.
# 1187896  A whimsical series of collectible pins and sti...
# 1188138  Magical potion-themed pins inspired by the sol...
# 1188236  Furry anthro playing cards with corresponding ...
# 1188732                                 A custom card deck
#
#                                                   category  \
# 0        {"id":46,"name":"Children's Books","slug":"pub...
# 10       {"id":28,"name":"Product Design","slug":"desig...
# 17       {"id":28,"name":"Product Design","slug":"desig...
# 24       {"id":28,"name":"Product Design","slug":"desig...
# 25       {"id":28,"name":"Product Design","slug":"desig...
# ...                                                    ...
# 1187809  {"id":12,"name":"Games","slug":"games","positi...
# 1187896  {"id":1,"name":"Art","slug":"art","position":1...
# 1188138  {"id":1,"name":"Art","slug":"art","position":1...
# 1188236  {"id":273,"name":"Playing Cards","slug":"games...
# 1188732  {"id":273,"name":"Playing Cards","slug":"games...
#
#          converted_pledged_amount region          created_at  \
# 0                            6114     EU 2020-04-16 05:18:45
# 10                           5643     US 2020-05-27 06:47:29
# 17                           9857     US 2020-04-15 07:11:52
# 24                         116629     US 2016-12-27 13:19:41
# 25                          11880     US 2020-07-17 19:34:35
# ...                           ...    ...                 ...
# 1187809                       197     US 2020-07-08 15:17:30
# 1187896                      1298     US 2020-03-23 09:35:22
# %%
df.head()
# Out:
#                                                 blurb  \
# 0   Help Guy and Steph publish their illustrated c...
# 10  Support us by backing! Wearable Blanket featur...
# 17  Yono Clip is the ultimate solution to keep you...
# 24  Our new go to mini rod is ready for all of you...
# 25  Looking for a menstrual cup that is comfortabl...
#
#                                              category  \
# 0   {"id":46,"name":"Children's Books","slug":"pub...
# 10  {"id":28,"name":"Product Design","slug":"desig...
# 17  {"id":28,"name":"Product Design","slug":"desig...
# 24  {"id":28,"name":"Product Design","slug":"desig...
# 25  {"id":28,"name":"Product Design","slug":"desig...
#
#     converted_pledged_amount region          created_at            deadline  \
# 0                       6114     EU 2020-04-16 05:18:45 2020-05-15 01:58:55
# 10                      5643     US 2020-05-27 06:47:29 2020-07-09 09:00:00
# 17                      9857     US 2020-04-15 07:11:52 2020-07-13 05:22:08
# 24                    116629     US 2016-12-27 13:19:41 2020-04-23 19:33:00
# 25                     11880     US 2020-07-17 19:34:35 2020-08-26 23:59:00
#
#     fx_rate     goal          id         launched_at  \
# 0   1.36408   2500.0  1846656783 2020-04-24 01:58:55
# 10  1.00000   5000.0  1091394927 2020-06-09 09:14:06
# 17  1.00000   7700.0  1892452780 2020-06-13 05:22:08
# 24  1.00000  10000.0   591954572 2020-03-24 10:02:22
# 25  1.00000  10000.0  1488247508 2020-07-28 08:05:39
#
#                                                  name    pledged       state  \
# 0   An Illustrated Children's Book - Kindness is C...    5008.00  successful
# 10  Snuggy Buddy Baby - The First Wearable Lovey B...    5643.00  successful
# 17                                          Yono Clip    9857.44  successful
# 24  Tenkara Rod Co. - The Beartooth Rod - Go Anywh...  116629.00  successful
# 25            Kind Cup - the innovative menstrual cup   11880.00  successful
#
#       state_changed_at    pledged_usd main_category      sub_category  \
# 0  2020-05-15 01:58:55    6172.413435    Publishing  Children's Books
# 10 2020-07-09 09:00:00    5643.000000        Design    Product Design
# 17 2020-07-13 05:22:08    9857.440000        Design    Product Design
# 24 2020-04-23 19:33:00  116629.000000        Design    Product Design
# 25 2020-08-26 23:59:01   11880.000000        Design    Product Design
#
#         goal_usd  campaign_duration
# 0    3410.199225                 21
# 10   5000.000000                 29
# 17   7700.000000                 30
# 24  10000.000000                 30
# 25  10000.000000                 29

# %%
df['create_to_launch_duration'] = (df['launched_at'] - df['created_at']).dt.days

# %%
df.head()
# Out:
#                                                 blurb  \
# 0   Help Guy and Steph publish their illustrated c...
# 10  Support us by backing! Wearable Blanket featur...
# 17  Yono Clip is the ultimate solution to keep you...
# 24  Our new go to mini rod is ready for all of you...
# 25  Looking for a menstrual cup that is comfortabl...
#
#                                              category  \
# 0   {"id":46,"name":"Children's Books","slug":"pub...
# 10  {"id":28,"name":"Product Design","slug":"desig...
# 17  {"id":28,"name":"Product Design","slug":"desig...
# 24  {"id":28,"name":"Product Design","slug":"desig...
# 25  {"id":28,"name":"Product Design","slug":"desig...
#
#     converted_pledged_amount region          created_at            deadline  \
# 0                       6114     EU 2020-04-16 05:18:45 2020-05-15 01:58:55
# 10                      5643     US 2020-05-27 06:47:29 2020-07-09 09:00:00
# 17                      9857     US 2020-04-15 07:11:52 2020-07-13 05:22:08
# 24                    116629     US 2016-12-27 13:19:41 2020-04-23 19:33:00
# 25                     11880     US 2020-07-17 19:34:35 2020-08-26 23:59:00
#
#     fx_rate     goal          id         launched_at  \
# 0   1.36408   2500.0  1846656783 2020-04-24 01:58:55
# 10  1.00000   5000.0  1091394927 2020-06-09 09:14:06
# 17  1.00000   7700.0  1892452780 2020-06-13 05:22:08
# 24  1.00000  10000.0   591954572 2020-03-24 10:02:22
# 25  1.00000  10000.0  1488247508 2020-07-28 08:05:39
#
#                                                  name    pledged       state  \
# 0   An Illustrated Children's Book - Kindness is C...    5008.00  successful
# 10  Snuggy Buddy Baby - The First Wearable Lovey B...    5643.00  successful
# 17                                          Yono Clip    9857.44  successful
# 24  Tenkara Rod Co. - The Beartooth Rod - Go Anywh...  116629.00  successful
# 25            Kind Cup - the innovative menstrual cup   11880.00  successful
#
#       state_changed_at    pledged_usd main_category      sub_category  \
# 0  2020-05-15 01:58:55    6172.413435    Publishing  Children's Books
# 10 2020-07-09 09:00:00    5643.000000        Design    Product Design
# 17 2020-07-13 05:22:08    9857.440000        Design    Product Design
# 24 2020-04-23 19:33:00  116629.000000        Design    Product Design
# 25 2020-08-26 23:59:01   11880.000000        Design    Product Design
#
#         goal_usd  campaign_duration  create_to_launch_duration
# 0    3410.199225                 21                          7
# 10   5000.000000                 29                         13
# 17   7700.000000                 30                         58
# 24  10000.000000                 30                       1182
# 25  10000.000000                 29                         10

# %% [markdown]
# ### Get failed targets

# %%
df.state.value_counts(normalize=True)
# Out:
# successful    0.768566
# failed        0.231434
# Name: state, dtype: float64

# %%
df['Failed'] = (df['state'] == 'failed').astype(int)

# %%
df.head(20)
# Out:
#                                                  blurb  \
# 0    Help Guy and Steph publish their illustrated c...
# 10   Support us by backing! Wearable Blanket featur...
# 17   Yono Clip is the ultimate solution to keep you...
# 24   Our new go to mini rod is ready for all of you...
# 25   Looking for a menstrual cup that is comfortabl...
# 45   Optimize how you perform and feel. Dial in any...
# 57   An inheritable writing instrument created with...
# 60   A powder-coated steel hammock hitch that attac...
# 84   Recycled Ocean plastic & Cotton waste turned i...
# 86   FableWood is back with cute and cuddly creatio...
# 94   Adventure with the Mitch Mason Chronicle, a da...
# 96   An artisan smoked meats business that gives ba...
# 98   Housemade Italian flat bread sandwiches and ot...
# 100  Use the natural Anti-Microbial power of Solid ...
# 101  Revolutionizing the way a fade haircut is done...
# 107  Visually mesmerizing, strangely satisfying, Bu...
# 108  Vegan camera straps made from cork. Made in Po...
# 109  FINO is the holster inspired hybrid sling pack...
# 110  An editorial look book featuring queer and tra...
# 121  Inspired by what Neil deGrasse Tyson called “t...
#
#                                               category  \
# 0    {"id":46,"name":"Children's Books","slug":"pub...
# 10   {"id":28,"name":"Product Design","slug":"desig...
# 17   {"id":28,"name":"Product Design","slug":"desig...
# 24   {"id":28,"name":"Product Design","slug":"desig...
# 25   {"id":28,"name":"Product Design","slug":"desig...
# 86                          43       0
# 94                         435       0
# 96                          28       0
# 98                           1       1
# 100                          9       0
# 101                         32       0
# 107                         86       0
# 108                          9       0
# 109                         40       0
# 110                          4       0
# 121                         65       0
#
# [20 rows x 21 columns]

# %%
df.Failed.value_counts(normalize=True)
# Out:
# 0    0.768566
# 1    0.231434
# Name: Failed, dtype: float64

# %% [markdown]
# ### drop the irrelevant columns

# %%
df.columns
# Out:
# Index(['blurb', 'category', 'converted_pledged_amount', 'region', 'created_at',
#        'deadline', 'fx_rate', 'goal', 'id', 'launched_at', 'name', 'pledged',
#        'state', 'state_changed_at', 'pledged_usd', 'main_category',
#        'sub_category', 'goal_usd', 'campaign_duration',
#        'create_to_launch_duration', 'Failed'],
#       dtype='object')

# %%
df.drop(df[['blurb', 'category', 'converted_pledged_amount', 'fx_rate', 'goal',
           'name', 'pledged', 'state', 'state_changed_at']], axis = 1, inplace = True)

# %%
df.head()
# Out:
#    region          created_at            deadline          id  \
# 0      EU 2020-04-16 05:18:45 2020-05-15 01:58:55  1846656783
# 10     US 2020-05-27 06:47:29 2020-07-09 09:00:00  1091394927
# 17     US 2020-04-15 07:11:52 2020-07-13 05:22:08  1892452780
# 24     US 2016-12-27 13:19:41 2020-04-23 19:33:00   591954572
# 25     US 2020-07-17 19:34:35 2020-08-26 23:59:00  1488247508
#
#            launched_at    pledged_usd main_category      sub_category  \
# 0  2020-04-24 01:58:55    6172.413435    Publishing  Children's Books
# 10 2020-06-09 09:14:06    5643.000000        Design    Product Design
# 17 2020-06-13 05:22:08    9857.440000        Design    Product Design
# 24 2020-03-24 10:02:22  116629.000000        Design    Product Design
# 25 2020-07-28 08:05:39   11880.000000        Design    Product Design
#
#         goal_usd  campaign_duration  create_to_launch_duration  Failed
# 0    3410.199225                 21                          7       0
# 10   5000.000000                 29                         13       0
# 17   7700.000000                 30                         58       0
# 24  10000.000000                 30                       1182       0
# 25  10000.000000                 29                         10       0

# %%
df.set_index('id', inplace = True)

# %%
df.head()
# Out:
#            region          created_at            deadline         launched_at  \
# id
# 1846656783     EU 2020-04-16 05:18:45 2020-05-15 01:58:55 2020-04-24 01:58:55
# 1091394927     US 2020-05-27 06:47:29 2020-07-09 09:00:00 2020-06-09 09:14:06
# 1892452780     US 2020-04-15 07:11:52 2020-07-13 05:22:08 2020-06-13 05:22:08
# 591954572      US 2016-12-27 13:19:41 2020-04-23 19:33:00 2020-03-24 10:02:22
# 1488247508     US 2020-07-17 19:34:35 2020-08-26 23:59:00 2020-07-28 08:05:39
#
#               pledged_usd main_category      sub_category      goal_usd  \
# id
# 1846656783    6172.413435    Publishing  Children's Books   3410.199225
# 1091394927    5643.000000        Design    Product Design   5000.000000
# 1892452780    9857.440000        Design    Product Design   7700.000000
# 591954572   116629.000000        Design    Product Design  10000.000000
# 1488247508   11880.000000        Design    Product Design  10000.000000
#
#             campaign_duration  create_to_launch_duration  Failed
# id
# 1846656783                 21                          7       0
# 1091394927                 29                         13       0
# 1892452780                 30                         58       0
# 591954572                  30                       1182       0
# 1488247508                 29                         10       0

# %%
df.to_csv('data_post_pandemic.csv')
